# %%
import torch
from torchvision import transforms
from PIL import Image
import matplotlib.pyplot as plt
import numpy as np

# %%
img = Image.open("monkey.jpg")
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=976x549>

# %%
import torch
import numpy as np
import matplotlib.pyplot as plt

import torchvision.transforms.functional as F


plt.rcParams["savefig.bbox"] = 'tight'


def show(imgs):
    if not isinstance(imgs, list):
        imgs = [imgs]
    fig, axs = plt.subplots(ncols=len(imgs), squeeze=False)
    
    for i, img in enumerate(imgs):
        img = img.detach()
        img = F.to_pil_image(img)
        axs[0, i].imshow(np.asarray(img))
        axs[0, i].set(xticklabels=[], yticklabels=[], xticks=[], yticks=[])

# %%
from torchvision.utils import make_grid
from torchvision.io import read_image
from pathlib import Path

x = transforms.ToTensor()(img)
y = transforms.Normalize(x.mean(),x.std())(x)

dog_list = [x,y]

grid = make_grid(dog_list)
show(grid)

# %%
transformations = transforms.Compose([
    transforms.Resize((300,300)),
    transforms.RandomRotation(50), # Random rotation is often combined with center crop
    transforms.CenterCrop(200),
    transforms.Grayscale(),
    transforms.ToTensor(),
])
x = transformations(img)

norm = transforms.Normalize(x.mean(),x.std())
x = norm(x)
x
# Out:
# tensor([[[ 0.3751,  0.4115,  0.3207,  ...,  2.0098,  2.1369,  2.2822],
#          [ 0.4296,  0.4296,  0.3388,  ...,  2.1369,  2.1369,  2.2822],
#          [ 0.4296,  0.4296,  0.3933,  ...,  2.1369,  2.2822,  2.3912],
#          ...,
#          [-0.8599, -0.0608,  0.6113,  ...,  2.5183,  2.5002,  2.5002],
#          [-0.1152,  0.5749,  0.5749,  ...,  2.5183,  2.5002,  2.4820],
#          [-0.2061,  0.5386,  0.9019,  ...,  2.5002,  2.5002,  2.5002]]])

# %%
from torchvision.utils import make_grid
from torchvision.io import read_image
from pathlib import Path



_list = [x[0,:,:]]

grid = make_grid(_list)
show(grid)
